# %% [markdown]
# #Python Basics

# %% [markdown]
# # theory

# %% [markdown]
# 1 What is Python, and why is it popular ?
#      - Python is a programming language . It is very popular because
#      1-  of its vesatility
#      2- it is easy to learn
#      3-it has numerious libraries
#      4- supportive community
# 2  What is an interpreter in Python ?
#    - It can read and run program line by line
# 3 What are pre-defined keywords in Python?
#  - keywords in Python have fixed meaning .
#  ex- if , else , while....etc .
# 4 Can keywords be used as variable names ?
# - No
# 5  What is mutability in Python ?
#   - Mutability means we are able to change or edit the vlaue of a objet in python.
# 6 Why are lists mutable, but tuples are immutable ?
#   - Because value of list can be change but value of tuples can not.
# 7 What is the difference between “==” and “is” operators in Python
# - == checks if values are same or not whereas
#   is checks  vlaues are stored in same memory container.
# 8  What are logical operators in Python ?
#  - and , or ,not
# 9  What is type casting in Python ?
#   - It means converting data from one typr to anoter. ex- str to int.
# 10 What is the difference between implicit and explicit type casting ?
#  -Implicit casting: python converts automatically
#  -Explicit casting: Programmer converts manually using functions like int().
# 11 What is the purpose of conditional statements in Python ?
# - Conditional statements help the program make decisions using if,elif,else.
# 12 How does the elif statement work ?
# - If previous condition was false then elif checks another.
# 13 What is the difference between for and while loops ?
#  - For : used when you know exact number of repetitions.
#    while :

# %% [markdown]
# 1 What is Python, and why is it popular ?
#      - Python is a programming language . It is very popular because
#      1-  of its vesatility
#      2- it is easy to learn
#      3-it has numerious libraries
#      4- supportive community
# 2  What is an interpreter in Python ?
#    - It can read and run program line by line
# 3 What are pre-defined keywords in Python?
#  - keywords in Python have fixed meaning .
#  ex- if , else , while....etc .
# 4 Can keywords be used as variable names ?
# - No
# 5  What is mutability in Python ?
#   - Mutability means we are able to change or edit the vlaue of a objet in python.
# 6 Why are lists mutable, but tuples are immutable ?
#   - Because value of list can be change but value of tuples can not.
# 7 What is the difference between “==” and “is” operators in Python
# - == checks if values are same or not whereas
#   is checks  vlaues are stored in same memory container.
# 8  What are logical operators in Python ?
#  - and , or ,not
# 9  What is type casting in Python ?
#   - It means converting data from one typr to anoter. ex- str to int.
# 10 What is the difference between implicit and explicit type casting ?
#  -Implicit casting: python converts automatically
#  -Explicit casting: Programmer converts manually using functions like int().
# 11 What is the purpose of conditional statements in Python ?
# - Conditional statements help the program make decisions using if,elif,else.
# 12 How does the elif statement work ?
# - If previous condition was false then elif checks another.
# 13 What is the difference between for and while loops ?
#  - For : used when you know exact number of repetitions.
#    while :

# %% [markdown]
# 1 What is Python, and why is it popular ?
#      - Python is a programming language . It is very popular because
#      1-  of its vesatility
#      2- it is easy to learn
#      3-it has numerious libraries
#      4- supportive community
#
#
# 2  What is an interpreter in Python ?
#    - It can read and run program line by line
#
#
# 3 What are pre-defined keywords in Python?
#  - keywords in Python have fixed meaning .
# ex- if , else , while....etc .
#
#
#
# 4 Can keywords be used as variable names ?
# - No.
#
#
# 5  What is mutability in Python ?
#   - Mutability means we are able to change or edit the vlaue of a objet in python.
#
#
# 6 Why are lists mutable, but tuples are immutable ?
#   - Because value of list can be change but value of tuples can not.
#
#
# 7 What is the difference between “==” and “is” operators in Python
# - == checks if values are same or not whereas
#   is checks  vlaues are stored in same memory container.
#
#
# 8  What are logical operators in Python ?
#  - and , or ,not
#
#
# 9  What is type casting in Python ?
#   - It means converting data from one typr to anoter. ex- str to int.
#
#
# 10 What is the difference between implicit and explicit type casting ?
#  -Implicit casting: python converts automatically
#  -Explicit casting: Programmer converts manually using functions like int().
#
#
# 11 What is the purpose of conditional statements in Python ?
# - Conditional statements help the program make decisions using if,elif,else.
#
#
# 12 How does the elif statement work ?
# - If previous condition was false then elif checks another.
#
#
# 13 What is the difference between for and while loops ?
#  - For : used when you know exact number of repetitions.
#    while :

# %% [markdown]
# 1 What is Python, and why is it popular ?
#      - Python is a programming language . It is very popular because
#      1-  of its vesatility
#      2- it is easy to learn
#      3-it has numerious libraries
#      4- supportive community
#
#
# 2  What is an interpreter in Python ?
#    - It can read and run program line by line
#
#
# 3 What are pre-defined keywords in Python?
#  - keywords in Python have fixed meaning .
# ex- if , else , while....etc .
#
#
#
# 4 Can keywords be used as variable names ?
# - No.
#
#
# 5  What is mutability in Python ?
#   - Mutability means we are able to change or edit the vlaue of a objet in python.
#
#
# 6 Why are lists mutable, but tuples are immutable ?
#   - Because value of list can be change but value of tuples can not.
#
#
# 7 What is the difference between “==” and “is” operators in Python
# - == checks if values are same or not whereas
#   is checks  vlaues are stored in same memory container.
#
#
# 8  What are logical operators in Python ?
#  - and , or ,not
#
#
# 9  What is type casting in Python ?
#   - It means converting data from one typr to anoter. ex- str to int.
#
#
# 10 What is the difference between implicit and explicit type casting ?
#  -Implicit casting: python converts automatically
#  -Explicit casting: Programmer converts manually using functions like int().
#
#
# 11 What is the purpose of conditional statements in Python ?
# - Conditional statements help the program make decisions using if,elif,else.
#
#
# 12 How does the elif statement work ?
# - If previous condition was false then elif checks another.
#
#
# 13 What is the difference between for and while loops ?
#  - For : used when you know exact number of repetitions.
#    while : used when you don't know number of repetitions.
#
#
# 14 Describe a scenario where a while loop is more suitable than a for loop ?
#  - when you want input of correct password from user.

# %% [markdown]
# #Practical Question

# %%
# 1 Write a Python program to print "Hello, World!y
print("hello world!")
# 2 Write a Python program that displays your name and age
name = "Abdul"
age = "20"
print("name")
print("age")
# 3 Write code to print all the pre-defined keywords in Python using the keyword library
import keyword
print(keyword.kwlist)
# 4 Write a program that checks if a given word is a Python keyword.

word = input("Enter a word: ")
print(keyword.iskeyword(word))
#5  Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.
# List (mutable)
my_list = [1, 2, 3]
my_list[0] = 10

# Tuple (immutable)
my_tuple = (1, 2, 3)
# my_tuple[0] = 10  # This will cause an error

print("List:", my_list)
print("Tuple:", my_tuple)
#6 Write a function to demonstrate the behavior of mutable and immutable arguments.
def change_list(lst):
    lst[0] = 100   # Changes original list

def change_number(num):
    num = 100      # Does not change original number

l = [1, 2, 3]
n = 10

change_list(l)
change_number(n)

print("List after function:", l)
print("Number after function:", n)
#7 Write a program that performs basic arithmetic operations on two user-input numbers.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print(a > 10 and b > 10)
print(a > 10 or b > 10)
print(not(a > 10))
#8 . Write a program to demonstrate the use of logical operators.
   a = int(input("Enter a number: "))

if a > 0 and a < 100:
    print("The number is positive and less than 100.")
else:
    print("Condition is false.")
 #9 Write a Python program to convert user input from string to integer, float, and boolean types.
 a = "5"
a = int(a)
print(a)
#10 Write code to demonstrate type casting with list elements.
   numbers = ["5", "10", "15"]

a = int(numbers[0])
b = int(numbers[1])
c = int(numbers[2])

print(a, b, c)
#11 Write a program that checks if a number is positive, negative, or zero.
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")

#12. Write a for loop to print numbers from 1 to 10.
  i = 1

while i <= 10:
    print(i)
    i = i + 1
#13 Write a Python program to find the sum of all even numbers between 1 and 50.
 first = 2
last = 50
n = 25

sum_even = (n * (first + last)) // 2

print("Sum of even numbers from 1 to 50 is:", sum_even)
#14 Write a program to reverse a string using a while loop.
text = input("Enter a string: ")

i = len(text) - 1
rev = ""

while i >= 0:
    rev = rev + text[i]
    i = i

 #15 . Write a Python program to calculate the factorial of a number provided by the user using a while loop.
    n = int(input("Enter a number: "))

fact = 1
i = n

while i > 0:
    fact = fact * i
    i = i - 1

print("Factorial of", n, "is", fact)
